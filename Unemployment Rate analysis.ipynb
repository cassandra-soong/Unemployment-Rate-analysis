# %% [markdown]
# ## Unemployment Rate analysis

# %% [markdown]
# ### Goals of the analysis:
#
# 1. Which country in the EU has the highest / lowest unemployment rate in 1991 vs 2021?
# 2. What is the unemployment rate trend in United States and United Kingdom between 1991-2021?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
df = pd.read_csv("unemployment.csv")
df = df.set_index("Country Name")
df.head(
# Out:
#                             Country Code   1991   1992   1993   1994   1995  \
# Country Name
# Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84   7.83
# Afghanistan                          AFG  10.65  10.82  10.72  10.73  11.18
# Africa Western and Central           AFW   4.42   4.53   4.55   4.54   4.53
# Angola                               AGO   4.21   4.21   4.23   4.16   4.11
# Albania                              ALB  10.31  30.01  25.26  20.84  14.61
#
#                               1996   1997   1998   1999  ...   2012   2013  \
# Country Name                                             ...
# Africa Eastern and Southern   7.84   7.86   7.81   7.79  ...   6.56   6.45
# Afghanistan                  10.96  10.78  10.80  10.81  ...  11.34  11.19
# Africa Western and Central    4.57   4.60   4.66   4.86  ...   4.64   4.41
# Angola                        4.10   4.09   4.07   4.05  ...   7.35   7.37
# ...

# %% [markdown]
# ### Unemployment rate in EU in 1991

# %%
eu = df.loc[["Austria", "Belgium", "Bulgaria", "Croatia", 
             "Cyprus", "Czech Republic", "Denmark", "Estonia", 
             "Finland", "France", "Germany", "Greece", "Hungary",
             "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg",
             "Malta", "Netherlands", "Poland", "Portugal", "Romania", 
             "Slovenia", "Spain", "Sweden"], :]

eu.head()
# Out:
#              Country Code   1991   1992   1993   1994   1995   1996   1997  \
# Country Name
# Austria               AUT   3.42   3.59   4.25   3.54   4.35   5.28   5.15
# Belgium               BEL   6.99   6.70   8.08   9.65   9.34   9.48   8.96
# Bulgaria              BGR  11.10  15.30  16.40  12.80  11.10  12.50  13.70
# Croatia               HRV  11.14  11.01  10.68  10.63  10.17   9.68   9.71
# Cyprus                CYP   3.00   2.09   2.70   2.70   2.60   3.10   3.40
#
#                1998   1999  ...   2012   2013   2014   2015   2016   2017  \
# Country Name                ...
# Austria        5.52   4.70  ...   4.87   5.33   5.62   5.72   6.01   5.50
# Belgium        9.32   8.65  ...   7.54   8.43   8.52   8.48   7.83   7.09
# Bulgaria      12.20  14.10  ...  12.27  12.94  11.42   9.14   7.57   6.16
# Croatia       11.39  13.56  ...  15.93  17.25  17.29  16.18  13.10  11.21
# Cyprus         3.30   5.70  ...  11.80  15.87  16.09  14.91  12.95  11.05
#
# ...

# %%
eu_1991 = eu.loc[:, ["Country Code", "1991"]]
eu_1991 = eu_1991.sort_values(by=["1991"])

avg_eu_1991 = eu_1991["1991"].mean()

eu_1991.head()
# Out:
#                Country Code  1991
# Country Name
# Lithuania               LTU  1.10
# Estonia                 EST  1.47
# Luxembourg              LUX  1.48
# Czech Republic          CZE  2.27
# Latvia                  LVA  2.70

# %%
fig, ax = plt.subplots(figsize=(10,4))

ax.bar(x=eu_1991["Country Code"],
       height=eu_1991["1991"],
       width=0.4
)

ax.set_title("Unemployment rate in EU in 1991")
ax.set_xlabel("Countries")
ax.set_ylabel("Unemployment rate (%)")
ax.axhline(avg_eu_2021, color="black", ls=":", label="Average rate")
plt.legend(loc = 'upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Spain had the highest unemployment rate in 1991, while Lithuania had the lowest at 1.1%

# %% [markdown]
# ### Unemployment rate in EU in 2021

# %%
eu_2021 = eu.loc[:, ["Country Code", "2021"]]
eu_2021 = eu_2021.sort_values(by=["2021"])

avg_eu_2021 = eu_2021["2021"].mean()

eu_2021.head()
# Out:
#                Country Code  2021
# Country Name
# Czech Republic          CZE  2.89
# Poland                  POL  3.37
# Malta                   MLT  3.50
# Germany                 DEU  3.54
# Netherlands             NLD  4.01

# %%
fig, ax = plt.subplots(figsize=(10,4))

ax.bar(x=eu_2021["Country Code"],
       height=eu_2021["2021"],
       width=0.4
)

ax.set_title("Unemployment rate in EU in 2021")
ax.set_xlabel("Countries")
ax.set_ylabel("Unemployment rate (%)")
ax.axhline(avg_eu_2021, color="black", ls=":", label="Average rate")
plt.legend(loc = 'upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Greece had the highest unemployment rate in 2021, whereas Czech Republic had the lowest rate 2.89%.

# %% [markdown]
# #### Countries such as Poland, Malta, Germany and Netherlands had an improvement in their unemployment rate as compared to 1991. However, the lowest unemployment rate is no longer below 2% in 2021, indicating more unemployments in the 21st century with a higher population.

# %% [markdown]
# ### Unemployment rate in U.S and U.K between 1991 - 2021

# %%
uk_us = df.loc[["United States", "United Kingdom"], :]
uk_us = uk_us.drop(["Country Code"], axis=1).T
uk_us.head()
# Out:
# Country Name  United States  United Kingdom
# 1991                   6.80            8.55
# 1992                   7.50            9.78
# 1993                   6.90           10.35
# 1994                   6.12            9.65
# 1995                   5.65            8.69

# %%
fig, ax = plt.subplots(figsize=(10,4))

ax.plot(
    uk_us.index,
    uk_us["United States"],
    color = "red",
    linewidth = 2,
    label = "United States"
)

ax.plot(
    uk_us.index,
    uk_us["United Kingdom"],
    color = "blue",
    linewidth = 2,
    label = "United Kingdom"
)

ax.set_title("Unemployment rate in U.S and U.K between 1991-2021")
ax.set_xlabel("Year")
ax.set_ylabel("Unemployment rate (%)")
ax.set_xticks(uk_us.index[::2])
ax.axvline(16.5, c="black", ls="--")
ax.text(9, 7, "Global Financial Crisis-->")
ax.legend()

plt.show()

# %% [markdown]
# #### The unemployment rate in U.S and U.K both had similar trends. It decreased drastically over the years between 1993-2001 where more job opportunities were available. However, the unemployment rate spiked again between year 2008-2009 due to the Global Financial Crisis.
